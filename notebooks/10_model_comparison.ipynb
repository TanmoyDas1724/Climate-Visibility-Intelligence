# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
comparison = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Decision Tree",
        "Random Forest",
        "Baseline XGBoost",
        "Tuned XGBoost"
    ],
    "MAE": [
        2.4960,
        1.5368,
        1.1873,
        1.4365,
        1.1977
    ],
    "RMSE": [
        3.0290,
        2.2878,
        1.8434,
        2.0404,
        1.7759
    ],
    "R² Score": [
        0.4813,
        0.7041,
        0.8079,
        0.7646,
        0.8217
    ]
})

comparison
# Out:
#                Model     MAE    RMSE  R² Score
# 0  Linear Regression  2.4960  3.0290    0.4813
# 1      Decision Tree  1.5368  2.2878    0.7041
# 2      Random Forest  1.1873  1.8434    0.8079
# 3   Baseline XGBoost  1.4365  2.0404    0.7646
# 4      Tuned XGBoost  1.1977  1.7759    0.8217

# %%
comparison.sort_values(
    by="R² Score",
    ascending=False
)
# Out:
#                Model     MAE    RMSE  R² Score
# 4      Tuned XGBoost  1.1977  1.7759    0.8217
# 2      Random Forest  1.1873  1.8434    0.8079
# 3   Baseline XGBoost  1.4365  2.0404    0.7646
# 1      Decision Tree  1.5368  2.2878    0.7041
# 0  Linear Regression  2.4960  3.0290    0.4813

# %%
plt.figure(figsize=(8,5))

plt.bar(
    comparison["Model"],
    comparison["R² Score"]
)

plt.title("R² Score Comparison of Machine Learning Models")
plt.xlabel("Models")
plt.ylabel("R² Score")

plt.xticks(rotation=20)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.bar(
    comparison["Model"],
    comparison["MAE"]
)

plt.title("MAE Comparison of Machine Learning Models")
plt.xlabel("Models")
plt.ylabel("Mean Absolute Error")

plt.xticks(rotation=20)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.bar(
    comparison["Model"],
    comparison["RMSE"]
)

plt.title("RMSE Comparison of Machine Learning Models")
plt.xlabel("Models")
plt.ylabel("Root Mean Squared Error")

plt.xticks(rotation=20)

plt.show()

# %%
best_model = comparison.loc[
    comparison["R² Score"].idxmax()
]

best_model
# Out:
# Model       Tuned XGBoost
# MAE                1.1977
# RMSE               1.7759
# R² Score           0.8217
# Name: 4, dtype: object

# %%
print("Best Model Selected for Deployment:\n")

print(best_model)
# Out:
# Best Model Selected for Deployment:
#
# Model       Tuned XGBoost
# MAE                1.1977
# RMSE               1.7759
# R² Score           0.8217
# Name: 4, dtype: object

# %% [markdown]
# ## Final Recommendation
#
# Among all trained models, the Tuned XGBoost Regressor achieved the best overall performance.
#
# Performance:
#
# - MAE : 1.1977
# - RMSE : 1.7759
# - R² Score : 0.8217
#
# Therefore, the Tuned XGBoost model is selected for deployment in the Climate Visibility Intelligence Dashboard.
